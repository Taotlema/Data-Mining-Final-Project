# %% [markdown]
# ## Qestion here

# %%
# !pip uninstall seaborn matplotlib pandas -y

# !pip install seaborn matplotlib pandas
# Out:
# Found existing installation: seaborn 0.13.2
# Uninstalling seaborn-0.13.2:
#   Successfully uninstalled seaborn-0.13.2
# Found existing installation: matplotlib 3.10.7
# Uninstalling matplotlib-3.10.7:
#   Successfully uninstalled matplotlib-3.10.7
# Found existing installation: pandas 2.3.3
# Uninstalling pandas-2.3.3:
#   Successfully uninstalled pandas-2.3.3
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\madis\anaconda3\envs\ITCS3162-DataMining\Lib\site-packages\~atplotlib'.
# You can safely remove it manually.
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.10.7-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting pandas
#   Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\madis\anaconda3\envs\itcs3162-datamining\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\madis\anaconda3\envs\itcs3162-datamining\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\madis\anaconda3\envs\itcs3162-datamining\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\madis\anaconda3\envs\itcs3162-datamining\lib\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\madis\anaconda3\envs\itcs3162-datamining\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\madis\anaconda3\envs\itcs3162-datamining\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\madis\anaconda3\envs\itcs3162-datamining\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\madis\anaconda3\envs\itcs3162-datamining\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\madis\anaconda3\envs\itcs3162-datamining\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\madis\anaconda3\envs\itcs3162-datamining\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\madis\anaconda3\envs\itcs3162-datamining\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\madis\anaconda3\envs\itcs3162-datamining\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached matplotlib-3.10.7-cp312-cp312-win_amd64.whl (8.1 MB)
# Using cached pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
# Installing collected packages: pandas, matplotlib, seaborn
#
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ---------------------------------------- 0/3 [pandas]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    ------------- -------------------------- 1/3 [matplotlib]
#    -------------------------- ------------- 2/3 [seaborn]
#    -------------------------- ------------- 2/3 [seaborn]
#    -------------------------- ------------- 2/3 [seaborn]
#    -------------------------- ------------- 2/3 [seaborn]
#    -------------------------- ------------- 2/3 [seaborn]
#    -------------------------- ------------- 2/3 [seaborn]
#    ---------------------------------------- 3/3 [seaborn]
#
# Successfully installed matplotlib-3.10.7 pandas-2.3.3 seaborn-0.13.2

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df =  pd.read_csv('Data files/comodity2017.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of          SHIPMT_ID  ORIG_STATE  ORIG_MA ORIG_CFS_AREA  DEST_STATE  DEST_MA  \
# 0                1           6    99999      06-99999           6      260
# 1                2          49      482        49-482          47      314
# 2                3           6      348        06-348           6      348
# 3                4           6      260        06-260           6    99999
# 4                5          45      273        45-273          45      273
# ...            ...         ...      ...           ...         ...      ...
# 1048570    1048571          40      538        40-538          40      416
# 1048571    1048572          51    40060      51-40060          24    99999
# 1048572    1048573          48      206        48-206           8      216
# 1048573    1048574          36    99999      36-99999          42    99999
# 1048574    1048575          54    99999      54-99999          54    99999
#
#         DEST_CFS_AREA  NAICS  QUARTER SCTG  MODE  SHIPMT_VALUE  SHIPMT_WGHT  \
# 0              06-260    326        4   43     5          4380          391
# 1              47-314   4541        3   43    14            56            4
# 2              06-348   4231        4   34     5           255          440
# 3            06-99999    212        4   11     5           250        44912
# 4              45-273  45431        4   19     5            46           73
# ...               ...    ...      ...  ...   ...           ...          ...
# 1048570        40-416   4235        1   32     4          1380         3702
# 1048571      24-99999    323        3   29    14            64           32
# 1048572        08-216    332        4   33    14           243           14
# 1048573      42-99999   4249        4    9     5          7921           84
# 1048574      54-99999    324        3   19     4          1619        54988
#
#          SHIPMT_DIST_GC  SHIPMT_DIST_ROUTED TEMP_CNTL_YN EXPORT_YN  \
# 0                    54                  60            N         N
# 1                  1524                1810            N         N
# 2                     2                   5            N         N
# 3                    30                  35            N         N
# 4                     9                  11            N         N
# ...                 ...                 ...          ...       ...
# 1048570             108                 117            N         N
# 1048571             165                 209            N         N
# 1048572             690                 828            N         N
# 1048573              17                  20            N         N
# 1048574              10                  10            Y         N
#
#         EXPORT_CNTRY HAZMAT  WGT_FACTOR
# 0                  N      N       328.3
# 1                  N      N      8425.3
# 2                  N      N      9120.7
# 3                  N      N        20.9
# 4                  N      H      1733.8
# ...              ...    ...         ...
# 1048570            N      N       556.1
# 1048571            N      N        64.3
# 1048572            N      N       227.0
# 1048573            N      N       480.3
# 1048574            N      N      1035.9
#
# [1048575 rows x 20 columns]>

# %%
#Top States by Total Shipment Value (Outbound Shipment Value)
state_value = df.groupby("ORIG_STATE")["SHIPMT_VALUE"].sum().reset_index()
state_value = state_value.sort_values("SHIPMT_VALUE", ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(data=state_value, x="ORIG_STATE", y="SHIPMT_VALUE")
plt.title("Top 10 States by Total Outbound Shipment Value (2017)")
plt.xlabel("Origin State")
plt.ylabel("Total Shipment Value ($)")
plt.show()

# %%
#Transportation Mode Distribution
mode_counts = df["MODE"].value_counts().reset_index()
mode_counts.columns = ["MODE", "COUNT"]

plt.figure(figsize=(8,6))
sns.barplot(data=mode_counts, x="MODE", y="COUNT")
plt.title("Distribution of Transportation Modes (National)")
plt.xlabel("Transportation Mode Code")
plt.ylabel("Number of Shipments")
plt.show()

# %%
#Shipment Distance Distribution
plt.figure(figsize=(10,6))
sns.histplot(df["SHIPMT_DIST_GC"], bins=40, kde=True)
plt.title("Distribution of Shipment Distances (Great Circle Miles)")
plt.xlabel("Distance (Miles)")
plt.ylabel("Number of Shipments")
plt.show()
